# %%
# %matplotlib inline
import numpy
import matplotlib.pyplot as plt
from matplotlib import rcParams
rcParams['font.family'] = 'serif'
rcParams['font.size'] = 16
from matplotlib import animation
from JSAnimation.IPython_display import display_animation
from matplotlib.lines import Line2D
from traffic import rho_red_light, computeF

# %%
def get_vars(u):
    
    vel = u[1,:,:]/u[0,:,:]
    pres = (gamma - 1)*(u[2,:,:] - .5 * u[1,:,:]**2 / u[0,:,:])
    rho = u[0,:,:]
    
    return vel, pres, rho

def build_u(ICL,ICR,nx):
    
    u = numpy.zeros((3,nx))
    
    u[0,:nx/2] = ICL[0]
    u[1,:nx/2] = ICL[1]*ICL[0]
    u[2,:nx/2] = 0.5*ICL[1]**2/ICL[0]+ICL[2]/(gamma-1)
    
    u[0,nx/2:] = ICR[0]
    u[1,nx/2:] = ICR[1]*ICR[0]
    u[2,nx/2:] = 0.5*ICR[1]**2/ICR[0]+ICR[2]/(gamma-1)
    
    return u

def compute_F(u):
    
    u1, u2, u3 = u[0], u[1], u[2]
    f = numpy.array([u2,\
                  u2**2/u1+(gamma-1)*(u3-u2**2/(2*u1)),\
                  u2/u1*(u3+(gamma-1)*(u3-u2**2/(2*u1)))])
    return f

def ICs():

    ICL = numpy.zeros((3,1))
    ICR = numpy.zeros_like(ICL)
    
    ICL[0] = 1. 
    ICL[1] = 0.
    ICL[2] = 100.
    
    ICR[0] = .125
    ICR[1] = 0.
    ICR[2] = 10.
    
    return (ICL,ICR)

# %%
def rho_green_light(nx, rho_max, rho_light):
    """Computes "green light" initial condition with shock, and linear distribution behind

    Parameters
    ----------
    nx        : int
        Number of grid points in x
    rho_max   : float
        Maximum allowed car density
    rho_light : float
        Density of cars at stoplight

    Returns
    -------
    rho: array of floats
        Array with initial values of density
    """    
    rho = numpy.arange(nx)*2./nx*rho_light  # Before stoplight
    rho[(nx-1)/2:] = 0
    
    return rho

# %%
def animate(frame):
    x = numpy.arange(0,nx)
    x = (x-nx/2)*dx
    y = varview[:,frame]
    line.set_data(x,y)
    return line,
    
#def animate(data):
#    x = numpy.linspace(0,4,nx)
#    y = data
#    line.set_data(x,y)
#    return line,

# %%
def godunov(rho, nt, dt, dx, rho_max, V_max):
    """ Computes the solution with the Godunov scheme using the Lax-Friedrichs flux.
    
    Parameters
    ----------
    rho    : array of floats
            Density at current time-step
    nt     : int
            Number of time steps
    dt     : float
            Time-step size
    dx     : float
            Mesh spacing
    rho_max: float
            Maximum allowed car density
    V_max  : float
            Speed limit
    
    Returns
    -------
    rho_n : array of floats
            Density after nt time steps at every point x
    """
    
    #initialize our results array with dimensions nt by nx
    rho_n = numpy.zeros((nt,len(rho)))      
    #copy the initial u array into each row of our new array
    rho_n[:,:] = rho.copy()              
    
    #setup some temporary arrays
    rho_plus = numpy.zeros_like(rho)
    rho_minus = numpy.zeros_like(rho)
    flux = numpy.zeros_like(rho)
  
    for t in range(1,nt):
        
        rho_plus[:-1] = rho[1:] # Can't do i+1/2 indices, so cell boundary
        rho_minus[:] = rho[:] # arrays at index i are at location i+1/2
        flux = 0.5 * (computeF(V_max, rho_max, rho_minus) + 
                      computeF(V_max, rho_max, rho_plus) + 
                      dx / dt * (rho_minus - rho_plus))
        rho_n[t,1:-1] = rho[1:-1] + dt/dx*(flux[:-2]-flux[1:-1])
        rho_n[t,0] = rho[0]
        rho_n[t,-1] = rho[-1]
        rho = rho_n[t].copy()
        
    return rho_n

# %%
def minmod(e, dx, nx):
    """
    Compute the minmod approximation to the slope
    
    Parameters
    ----------
    e  : array of float 
        input data
    dx : float 
        spacestep
    nx : int
        number of spacial steps
    
    Returns
    -------
    sigma : array of float 
            minmod slope
    """
    
    sigma = numpy.zeros_like(e)
    de_minus = numpy.ones_like(e)
    de_plus = numpy.ones_like(e)
    
    de_minus[:,1:] = e[:,1:] - e[:,:-1]
    de_plus[:,:-1] = e[:,:-1] - e[:,1:]
    # The following is inefficient but easy to read
    for j in range(1,3):
        for i in range(1, nx-1):
            if (de_minus[j,i] * de_plus[j,i] < 0.0):
                sigma[j,i] = 0.0
            elif (numpy.abs(de_minus[j,i]) < numpy.abs(de_plus[j,i])):
                sigma[j,i] = de_minus[j,i]
            else:
                sigma[j,i] = de_plus[j,i]
    return sigma

# %%
def muscl(uf, nt, dt, dx, nx):
    """ Computes the solution with the MUSCL scheme using the Lax-Friedrichs flux,
    RK2 in time and minmod slope limiting.
    
    Parameters
    ----------
    uf     : array of floats
            Array u at current time-step
    nt     : int
            Number of time steps
    dt     : float
            Time-step size
    dx     : float
            Mesh spacing
    nx     : int
            Number of spacial steps
    
    Returns
    -------
    un : array of floats
            Array u after nt time steps at every point x
    """
    
    #initialize our results array with dimensions 3 by nx by nt
    un = numpy.zeros((3,nx,nt))      
    #copy the initial u array into each row of our new array
    un[:,:,0] = uf.copy()              
    
    #setup some temporary arrays
    un_plus = numpy.zeros_like(uf)
    un_minus = numpy.zeros_like(uf)
    flux = numpy.zeros_like(uf)
    un_star = numpy.zeros_like(uf)

    for t in range(1,nt):
               
        sigma = minmod(uf,dx,nx) #calculate minmod slope

        #reconstruct values at cell boundaries
        un_plus[:,:-1] = uf[:,1:] + sigma[:,1:]*dx/2.
        un_minus = uf - sigma*dx/2.
        
        flux = 0.5 * (compute_F(un_minus) + 
                      compute_F(un_plus) + 
                      dx / dt * (un_minus - un_plus))
        
        un_star[:,1:-1] = uf[:,1:-1] + dt/dx*(flux[:,:-2]-flux[:,1:-1])
        un_star[:,0] = uf[:,0]
        un_star[:,-1] = uf[:,-1]
        
        
        sigma = minmod(un_star,dx,nx) #calculate minmod slope
    
        #reconstruct values at cell boundaries
        un_plus[:,:-1] = un_star[:,1:] + sigma[:,1:]*dx/2.
        un_minus = un_star - sigma*dx/2.
        
        
        flux = 0.5 * (compute_F(un_minus) + 
                      compute_F(un_plus) + 
                      dx / dt * (un_minus - un_plus))
        
        un[:,1:-1,t] = 0.5 * (uf[:,1:-1] + un_star[:,1:-1] + 
                               dt/dx*(flux[:,:-2]-flux[:,1:-1]))
        un[:,0,t] = uf[:,0]
        un[:,-1,t] = uf[:,-1]
        uf = un[:,:,t].copy()
        
    return un

# %% [markdown]
# #Basic initial condition parameters
# #defining grid size, time steps, CFL condition, etc...
# nx = 81
# nt = 30
# dx = 4.0/nx
#
# rho_in = 5.
# rho_max = 10.
# V_max = 1.0
# x = numpy.linspace(0,4,nx)
#
# #make sure that u is set to our expected initial conditions
# rho = rho_red_light(nx, rho_max, rho_in)
# #rho = rho_green_light(nx, rho_max, rho_in)
# rho_n = muscl(rho, nt, dt, dx, rho_max, V_max)
#
# fig = plt.figure();
# ax = plt.axes(xlim=(0,4),ylim=(0.75*rho_in,1.25*rho_max),xlabel=('Distance'),ylabel=('Traffic density'));
# line, = ax.plot([],[],color='#003366', lw=2);
#
# anim = animation.FuncAnimation(fig, animate, frames=rho_n, interval=50)
# display_animation(anim, default_mode='loop')

# %%
nx = 161
nt = 61
dx = 20./(nx-1)
gamma = 1.4

sigma = .08
dt = sigma*dx

ICL,ICR = ICs()
uf = build_u(ICL,ICR,nx)
ut = muscl(uf,nt,dt,dx,nx)
vel,pres,rho = get_vars(ut)

varview = vel.copy()
fig = plt.figure();
ax = plt.axes(xlim=(-nx/2*dx,nx/2*dx),ylim=(0,numpy.amax(varview)*1.5));
line, = ax.plot([],[],lw=2);
anim = animation.FuncAnimation(fig, animate, nt, interval=50)
display_animation(anim, default_mode='loop')
# Out:
# <script language="javascript">
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     document.getElementById(this.slider_id).max = this.frames.length - 1;
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src = this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function(){t.anim_step_forward();}, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function(){t.anim_step_reverse();}, this.interval);
#   }
# </script>
#
# <div class="animation" align="center">
#     <img id="_anim_imgMOMLCOLPUXUTYWRC">
#     <br>
#     <input id="_anim_sliderMOMLCOLPUXUTYWRC" type="range" style="width:350px" name="points" min="0" max="1" step="1" value="0" onchange="animMOMLCOLPUXUTYWRC.set_frame(parseInt(this.value));"></input>
#     <br>
#     <button onclick="animMOMLCOLPUXUTYWRC.slower()">&#8211;</button>
#     <button onclick="animMOMLCOLPUXUTYWRC.first_frame()"><img class="anim_icon" src="data:image/png;base64,..."></button>
#     <button onclick="animMOMLCOLPUXUTYWRC.previous_frame()"><img class="anim_icon" src="data:image/png;base64,..."></button>
#     <button onclick="animMOMLCOLPUXUTYWRC.reverse_animation()"><img class="anim_icon" src="data:image/png;base64,..."></button>
#     <button onclick="animMOMLCOLPUXUTYWRC.pause_animation()"><img class="anim_icon" src="..."></button>
#     <button onclick="animMOMLCOLPUXUTYWRC.play_animation()"><img class="anim_icon" src="data:image/png;base64,..."></button>
#     <button onclick="animMOMLCOLPUXUTYWRC.next_frame()"><img class="anim_icon" src="data:image/png;base64,..."></button>
#     <button onclick="animMOMLCOLPUXUTYWRC.last_frame()"><img class="anim_icon" src="data:image/png;base64,..."></button>
#     <button onclick="animMOMLCOLPUXUTYWRC.faster()">+</button>
#   <form action="#n" name="_anim_loop_selectMOMLCOLPUXUTYWRC" class="anim_control">
#     <input type="radio" name="state" value="once" > Once </input>
#     <input type="radio" name="state" value="loop" checked> Loop </input>
#     <input type="radio" name="state" value="reflect" > Reflect </input>
#   </form>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_imgMOMLCOLPUXUTYWRC";
#     var slider_id = "_anim_sliderMOMLCOLPUXUTYWRC";
#     var loop_select_id = "_anim_loop_selectMOMLCOLPUXUTYWRC";
#     var frames = new Array(0);
#
#   frames[0] = "data:image/png;base64,..."
#   frames[1] = "data:image/png;base64,..."
#   frames[2] = "data:image/png;base64,..."
#   frames[3] = "data:image/png;base64,..."
#   frames[4] = "data:image/png;base64,..."
#   frames[5] = "data:image/png;base64,..."
#   frames[6] = "data:image/png;base64,..."
#   frames[7] = "data:image/png;base64,..."
#   frames[8] = "data:image/png;base64,..."
#   frames[9] = "data:image/png;base64,..."
#   frames[10] = "data:image/png;base64,..."
#   frames[11] = "data:image/png;base64,..."
#   frames[12] = "data:image/png;base64,..."
#   frames[13] = "data:image/png;base64,..."
#   frames[14] = "data:image/png;base64,..."
#   frames[15] = "data:image/png;base64,..."
#   frames[16] = "data:image/png;base64,..."
#   frames[17] = "data:image/png;base64,..."
#   frames[18] = "data:image/png;base64,..."
#   frames[19] = "data:image/png;base64,..."
#   frames[20] = "data:image/png;base64,..."
#   frames[21] = "data:image/png;base64,..."
#   frames[22] = "data:image/png;base64,..."
#   frames[23] = "data:image/png;base64,..."
#   frames[24] = "data:image/png;base64,..."
#   frames[25] = "data:image/png;base64,..."
#   frames[26] = "data:image/png;base64,..."
#   frames[27] = "data:image/png;base64,..."
#   frames[28] = "data:image/png;base64,..."
#   frames[29] = "data:image/png;base64,..."
#   frames[30] = "data:image/png;base64,..."
#   frames[31] = "data:image/png;base64,..."
#   frames[32] = "data:image/png;base64,..."
#   frames[33] = "data:image/png;base64,..."
#   frames[34] = "data:image/png;base64,..."
#   frames[35] = "data:image/png;base64,..."
#   frames[36] = "data:image/png;base64,..."
#   frames[37] = "data:image/png;base64,..."
#   frames[38] = "data:image/png;base64,..."
#   frames[39] = "data:image/png;base64,..."
#   frames[40] = "data:image/png;base64,..."
#   frames[41] = "data:image/png;base64,..."
#   frames[42] = "data:image/png;base64,..."
#   frames[43] = "data:image/png;base64,..."
#   frames[44] = "data:image/png;base64,..."
#   frames[45] = "data:image/png;base64,..."
#   frames[46] = "data:image/png;base64,..."
#   frames[47] = "data:image/png;base64,..."
#   frames[48] = "data:image/png;base64,..."
#   frames[49] = "data:image/png;base64,..."
#   frames[50] = "data:image/png;base64,..."
#   frames[51] = "data:image/png;base64,..."
#   frames[52] = "data:image/png;base64,..."
#   frames[53] = "data:image/png;base64,..."
#   frames[54] = "data:image/png;base64,..."
#   frames[55] = "data:image/png;base64,..."
#   frames[56] = "data:image/png;base64,..."
#   frames[57] = "data:image/png;base6

# %%
class SubplotAnimation(animation.TimedAnimation):
    def __init__(self):
        fig,axes = plt.subplots(nrows=3,figsize=(14,8));   

        self.line1 = Line2D([],[], color = 'black')
        self.line2 = Line2D([],[], color = 'red')
        self.line3 = Line2D([],[], color = 'blue')

        self.x = x
        self.vel = vel
        self.pres = pres
        self.rho = rho

        axes[0].set_xlim(-nx/2*dx,nx/2*dx)
        axes[0].set_ylim(0,numpy.amax(vel)*1.5)
        axes[0].add_line(self.line1)
        axes[1].set_xlim(-nx/2*dx,nx/2*dx)
        axes[1].set_ylim(0,numpy.amax(pres)*1.5)
        axes[1].add_line(self.line2)
        axes[2].set_xlim(-nx/2*dx,nx/2*dx)
        axes[2].set_ylim(0,numpy.amax(rho)*1.5)
        axes[2].add_line(self.line3)

        axes[0].set_ylabel("Velocity")
        axes[1].set_ylabel("Pressure")
        axes[2].set_xlabel("X Location (m)")
        axes[2].set_ylabel("Density")

        animation.TimedAnimation.__init__(self, fig, interval=50, blit=True)

    def _draw_frame(self, framedata):
        i = framedata
        self.line1.set_data(self.x, self.vel[:,i])
        self.line2.set_data(self.x, self.pres[:,i])
        self.line3.set_data(self.x, self.rho[:,i])

        self._drawn_artists = [self.line1, self.line2, self.line3]

    def new_frame_seq(self):
        return iter(range(nt))

    def _init_draw(self):
        lines =  [self.line1, self.line2, self.line3]
        for l in lines:
            l.set_data([], [])

# %%
x = numpy.arange(0,nx)
x = (x-nx/2)*dx
data = numpy.array([vel,pres,rho])

anim = SubplotAnimation()
display_animation(anim,default_mode='loop')
# Out:
# <script language="javascript">
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     document.getElementById(this.slider_id).max = this.frames.length - 1;
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src = this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function(){t.anim_step_forward();}, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function(){t.anim_step_reverse();}, this.interval);
#   }
# </script>
#
# <div class="animation" align="center">
#     <img id="_anim_imgGWBFKEOMUURAJFWQ">
#     <br>
#     <input id="_anim_sliderGWBFKEOMUURAJFWQ" type="range" style="width:350px" name="points" min="0" max="1" step="1" value="0" onchange="animGWBFKEOMUURAJFWQ.set_frame(parseInt(this.value));"></input>
#     <br>
#     <button onclick="animGWBFKEOMUURAJFWQ.slower()">&#8211;</button>
#     <button onclick="animGWBFKEOMUURAJFWQ.first_frame()"><img class="anim_icon" src="data:image/png;base64,..."></button>
#     <button onclick="animGWBFKEOMUURAJFWQ.previous_frame()"><img class="anim_icon" src="data:image/png;base64,..."></button>
#     <button onclick="animGWBFKEOMUURAJFWQ.reverse_animation()"><img class="anim_icon" src="data:image/png;base64,..."></button>
#     <button onclick="animGWBFKEOMUURAJFWQ.pause_animation()"><img class="anim_icon" src="..."></button>
#     <button onclick="animGWBFKEOMUURAJFWQ.play_animation()"><img class="anim_icon" src="data:image/png;base64,..."></button>
#     <button onclick="animGWBFKEOMUURAJFWQ.next_frame()"><img class="anim_icon" src="data:image/png;base64,..."></button>
#     <button onclick="animGWBFKEOMUURAJFWQ.last_frame()"><img class="anim_icon" src="data:image/png;base64,..."></button>
#     <button onclick="animGWBFKEOMUURAJFWQ.faster()">+</button>
#   <form action="#n" name="_anim_loop_selectGWBFKEOMUURAJFWQ" class="anim_control">
#     <input type="radio" name="state" value="once" > Once </input>
#     <input type="radio" name="state" value="loop" checked> Loop </input>
#     <input type="radio" name="state" value="reflect" > Reflect </input>
#   </form>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_imgGWBFKEOMUURAJFWQ";
#     var slider_id = "_anim_sliderGWBFKEOMUURAJFWQ";
#     var loop_select_id = "_anim_loop_selectGWBFKEOMUURAJFWQ";
#     var frames = new Array(0);
#
#   frames[0] = "data:image/png;base64,..."
#   frames[1] = "data:image/png;base64,..."
#   frames[2] = "data:image/png;base64,..."
#   frames[3] = "data:image/png;base64,..."
#   frames[4] = "data:image/png;base64,..."
#   frames[5] = "data:image/png;base64,..."
#   frames[6] = "data:image/png;base64,..."
#   frames[7] = "data:image/png;base64,..."
#   frames[8] = "data:image/png;base64,..."
#   frames[9] = "data:image/png;base64,..."
#   frames[10] = "data:image/png;base64,..."
#   frames[11] = "data:image/png;base64,..."
#   frames[12] = "data:image/png;base64,..."
#   frames[13] = "data:image/png;base64,..."
#   frames[14] = "data:image/png;base64,..."
#   frames[15] = "data:image/png;base64,..."
#   frames[16] = "data:image/png;base64,..."
#   frames[17] = "data:image/png;base64,..."
#   frames[18] = "data:image/png;base64,..."
#   frames[19] = "data:image/png;base64,..."
#   frames[20] = "data:image/png;base64,..."
#   frames[21] = "data:image/png;base64,..."
#   frames[22] = "data:image/png;base64,..."
#   frames[23] = "data:image/png;base64,..."
#   frames[24] = "data:image/png;base64,..."
#   frames[25] = "data:image/png;base64,..."
#   frames[26] = "data:image/png;base64,..."
#   frames[27] = "data:image/png;base64,..."
#   frames[28] = "data:image/png;base64,..."
#   frames[29] = "data:image/png;base64,..."
#   frames[30] = "data:image/png;base64,..."
#   frames[31] = "data:image/png;base64,..."
#   frames[32] = "data:image/png;base64,..."
#   frames[33] = "data:image/png;base64,..."
#   frames[34] = "data:image/png;base64,..."
#   frames[35] = "data:image/png;base64,..."
#   frames[36] = "data:image/png;base64,..."
#   frames[37] = "data:image/png;base64,..."
#   frames[38] = "data:image/png;base64,..."
#   frames[39] = "data:image/png;base64,..."
#   frames[40] = "data:image/png;base64,..."
#   frames[41] = "data:image/png;base64,..."
#   frames[42] = "data:image/png;base64,..."
#   frames[43] = "data:image/png;base64,..."
#   frames[44] = "data:image/png;base64,..."
#   frames[45] = "data:image/png;base64,..."
#   frames[46] = "data:image/png;base64,..."
#   frames[47] = "data:image/png;base64,..."
#   frames[48] = "data:image/png;base64,..."
#   frames[49] = "data:image/png;base64,..."
#   frames[50] = "data:image/png;base64,..."
#   frames[51] = "data:image/png;base64,..."
#   frames[52] = "data:image/png;base64,..."
#   frames[53] = "data:image/png;base64,..."
#   frames[54] = "data:image/png;base64,..."
#   frames[55] = "data:image/png;base64,..."
#   frames[56] = "data:image/png;base64,..."
#   frames[57] = "data:image/png;base6
